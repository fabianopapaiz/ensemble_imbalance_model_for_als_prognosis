# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import time


#needed to import utils.py
sys.path.append('../') 

import utils
import utils_preprocessing
import utils_exec_models

import numpy as np
import pandas as pd

from IPython.core.display import HTML

from IPython.display import clear_output


# Surpress warnings:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn


# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)


# %matplotlib inline

# %% [markdown]
# # Get and save the 10 best performances obtained by GridSearch grouping by ML algorithm

# %%
#read SINGLE-MODEL results
csv_file = 'exec_results/results_Single_Model.csv'
df_single_model = utils.read_csv(csv_file)
# display(df_single_model.head(3))

#read ENSEMBLE-IMBALANCE results
csv_file = 'exec_results/results_Ensemble_Imbalance.csv'
df_ens_imb = utils.read_csv(csv_file)
# display(df_ens_imb.head(3))


# get each algorithm analyzed
algorithms = list(df_single_model.Model.unique())
model_classes = list(df_single_model.Classifier.unique())
# print(model_classes)
# print(algorithms)

dir_dest = os.path.abspath('exec_results/')

# store all best models Object for both scenarios
best_models = list()

n_to_save = 25

for algorithm, model_class in zip(algorithms, model_classes):
    utils.print_string_with_separators(f'{algorithm} - {model_class}')
    
    # ==============================================================     
    # get the "n" best performances for the SINGLE-MODEL scenario
    # ==============================================================     
    print(f'   > SINGLE-MODEL ({n_to_save} best)')
    df_best_single_model = df_single_model.loc[(
          (df_single_model.Model == algorithm) 
    )].copy()

    
    # get and save the 5 best results for the algorithm    
    df_best_single_model = df_best_single_model.head(n_to_save)
#     display(df_best_single_model)
    csv_file = f'{dir_dest}/best_performances_{algorithm}_in_SINGLE_MODEL.csv'
    csv_file = csv_file.replace(' ', '_')
    utils.save_to_csv(df=df_best_single_model, csv_file=csv_file)

    # Get the best models and create instances using their hyperparameters    
    for model in utils_exec_models.get_models_object_from_results(df_best_single_model):
#         model['csv_file'] = csv_file
        best_models.append(model)
    
    
    
    # ==============================================================     
    # get the "n" best performances for the ENSEMBLE-IMBALANCE scenario
    # ==============================================================     
    print(f'   > ENSEMBLE-IMBALANCE ({n_to_save} best)')
    df_best_ens_imb = df_ens_imb.loc[(
          (df_ens_imb.Estimator_Desc == algorithm) 
    )].copy()

    
    # get and save the 5 best results for the algorithm    
    df_best_ens_imb = df_best_ens_imb.head(n_to_save)
#     display(df_best_ens_imb)
    csv_file = f'{dir_dest}/best_performances_{algorithm}_in_ENSEMBLE_IMBALANCE.csv'
    csv_file = csv_file.replace(' ', '_')
    utils.save_to_csv(df=df_best_ens_imb, csv_file=csv_file)
    
    # Get the best models and create instances using their hyperparameters    
    for model in utils_exec_models.get_models_object_from_results(df_best_ens_imb):
#         model['csv_file'] = csv_file
        best_models.append(model)
# Out:
# ---------
# SVM - SVC
# ---------
#    > SINGLE-MODEL (25 best)
# 25 samples were saved
#    > ENSEMBLE-IMBALANCE (25 best)
# 25 samples were saved
# --------------------------
# Naïve Bayes - ComplementNB
# --------------------------
#    > SINGLE-MODEL (25 best)
# 19 samples were saved
#    > ENSEMBLE-IMBALANCE (25 best)
# 25 samples were saved
# -------------------------------
# Neural Networks - MLPClassifier
# -------------------------------
#    > SINGLE-MODEL (25 best)
# 25 samples were saved
#    > ENSEMBLE-IMBALANCE (25 best)
# 25 samples were saved
# --------------------------------------
# Decision Tree - DecisionTreeClassifier
# --------------------------------------
#    > SINGLE-MODEL (25 best)
# 25 samples were saved
#    > ENSEMBLE-IMBALANCE (25 best)
# 25 samples were saved
# -----------------
# k-NN - GaussianNB
# -----------------
#    > SINGLE-MODEL (25 best)
# 25 samples were saved
#    > ENSEMBLE-IMBALANCE (25 best)
# 25 samples were saved
# -----------------------------------------
# Random Forest - RadiusNeighborsClassifier
# -----------------------------------------
#    > SINGLE-MODEL (25 best)
# 25 samples were saved
#    > ENSEMBLE-IMBALANCE (25 best)
# 25 samples were saved

# %% [markdown]
# ---
# ---
# # Reexecute each best model as following:
#
#  - ### Retrain the model using the full $Training$ set
#  - ### Validate the model using the $Validation$ set
#  - ### Save the $Validation$ $performances$

# %%
# %%time

csv_validation_performance = os.path.abspath('exec_results/validation_results.csv')



# verify if already exists an CSV with the results
overwrite_results_saved_previously = False

if os.path.exists(csv_validation_performance) and overwrite_results_saved_previously==False:
    print('Reading results saved previously...')
    df_validation_performance = utils.read_csv(csv_file=csv_validation_performance)
else:
    df_validation_performance = None


# Get the scaled Training and Validation subsets¶
X_train, y_train, X_valid, y_valid = utils.get_train_and_validation_data(scaled=True)

y_train = y_train[utils.CLASS_COLUMN].ravel()
y_valid = y_valid[utils.CLASS_COLUMN].ravel()


i = 0
tot = len(best_models)



## For each best model:
#    1. Retrain using using the Training data
#    2. Validate using the Validation data


for model_info in best_models:

    
    try:    

        # get the classifier name (without the parameters)
        model_instance = model_info['model_instance']
        scenario = model_info['Scenario']
        model = model_info['Model']
        model_params = model_info['Hyperparams']
        estimator = model_info['Estimator']
        estimator_params = model_info['Estimator_Hyperparams']

        model_str = f'{model}' + ('' if scenario=='Single-Model' else f'({estimator})')

        i += 1
        
        # check if model was already executed
        if df_validation_performance is not None:
            if scenario == 'Single-Model':
                df_executed = df_validation_performance.loc[
                    (df_validation_performance.Scenario == scenario)
                   &(df_validation_performance.Model == model) 
                   &(df_validation_performance.Model_Hyperparams == model_params) 
                   &(df_validation_performance.Estimator.isnull()) 
                   &(df_validation_performance.Estimator_Hyperparams.isnull()) 
                ].copy()
            else:
                df_executed = df_validation_performance.loc[
                    (df_validation_performance.Scenario == scenario)
                   &(df_validation_performance.Model == model) 
                   &(df_validation_performance.Model_Hyperparams == model_params) 
                   &(df_validation_performance.Estimator == estimator) 
                   &(df_validation_performance.Estimator_Hyperparams == estimator_params) 
                ].copy()
            
            if df_executed.shape[0] > 0:
                print(f'{i:>3} was already executed: {model_str} in "{scenario}" scenario')
                continue

        
        print(f'{i:>3}/{tot}: Executing {model_str} in "{scenario}" scenario',)

        # Retrain using the full traning set
        model_instance.fit(X_train, y_train)

        #predict using the Validation set
        y_pred = model_instance.predict(X_valid)

        #get Validation performance
        bal_acc, sens, spec, auc, acc, prec, f1 = utils_exec_models.get_scores_from_predict(
            y_validation=y_valid, 
            y_pred=y_pred, 
        )

        # Store the Validation and Training performances
        performance_to_save = {
            'Scenario': scenario,
            'Model': model,
            'Estimator': estimator,
            # Validation performance
            'Valid_BalAcc': bal_acc,
            'Valid_Sens'  : sens,
            'Valid_Spec'  : spec,
            'Valid_f1'    : f1,
            'Valid_AUC'   : auc,
            'Valid_Acc'   : acc,
            'Valid_Prec'  : prec,
            #
            'Model_Hyperparams': model_params,
            'Estimator_Hyperparams': estimator_params,
        }

        # create a dataFrame to store the performances
        df_aux = pd.DataFrame([performance_to_save])

        if df_validation_performance is None:
            df_validation_performance = df_aux
        else:
            df_validation_performance = pd.concat(
                [df_validation_performance, df_aux],
                ignore_index=True,
            )

    except Exception as ex:
        print('Instance')
        print(model_instance)
        print('INFO')
        print(model_info)
        print('ERROR')
        raise Exception(ex)
       


# sort the validation performances
df_validation_performance = utils_exec_models.sort_performances_results(
    df=df_validation_performance,
    cols_order_to_sort=[
        'Scenario', 
#         'Model', 
#         'Estimator', 
        'Valid_BalAcc', 
        'Valid_Sens', 
        'Valid_Spec'],
)



# save validation performances
utils.save_to_csv(
    df=df_validation_performance, 
    csv_file=csv_validation_performance
)
# Out:
# Reading results saved previously...
#   1/294: Executing SVM in "Single-Model" scenario
#   2/294: Executing SVM in "Single-Model" scenario
#   3/294: Executing SVM in "Single-Model" scenario
#   4/294: Executing SVM in "Single-Model" scenario
#   5/294: Executing SVM in "Single-Model" scenario
#   6/294: Executing SVM in "Single-Model" scenario
#   7/294: Executing SVM in "Single-Model" scenario
#   8/294: Executing SVM in "Single-Model" scenario
#   9/294: Executing SVM in "Single-Model" scenario
#  10/294: Executing SVM in "Single-Model" scenario
#  11/294: Executing SVM in "Single-Model" scenario
#  12/294: Executing SVM in "Single-Model" scenario
#  13/294: Executing SVM in "Single-Model" scenario
#  14/294: Executing SVM in "Single-Model" scenario
#  15/294: Executing SVM in "Single-Model" scenario
#  16/294: Executing SVM in "Single-Model" scenario
#  17/294: Executing SVM in "Single-Model" scenario
#  18/294: Executing SVM in "Single-Model" scenario
#  19/294: Executing SVM in "Single-Model" scenario
#  20/294: Executing SVM in "Single-Model" scenario
#  21/294: Executing SVM in "Single-Model" scenario
#  22/294: Executing SVM in "Single-Model" scenario
#  23/294: Executing SVM in "Single-Model" scenario
#  24/294: Executing SVM in "Single-Model" scenario
#  25/294: Executing SVM in "Single-Model" scenario
#  26/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  27/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  28/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  29/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  30/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  31/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  32/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  33/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  34/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  35/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  36/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  37/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  38/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  39/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  40/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  41/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  42/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  43/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  44/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  45/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  46/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  47/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  48/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  49/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  50/294: Executing Balanced-Bagging(SVM) in "Ensemble-Imbalance" scenario
#  51/294: Executing NB in "Single-Model" scenario
#  52/294: Executing NB in "Single-Model" scenario
#  53/294: Executing NB in "Single-Model" scenario
#  54/294: Executing NB in "Single-Model" scenario
#  55/294: Executing NB in "Single-Model" scenario
#  56/294: Executing NB in "Single-Model" scenario
#  57/294: Executing NB in "Single-Model" scenario
#  58/294: Executing NB in "Single-Model" scenario
#  59/294: Executing NB in "Single-Model" scenario
#  60/294: Executing NB in "Single-Model" scenario
#  61/294: Executing NB in "Single-Model" scenario
#  62/294: Executing NB in "Single-Model" scenario
#  63/294: Executing NB in "Single-Model" scenario
#  64/294: Executing NB in "Single-Model" scenario
#  65/294: Executing NB in "Single-Model" scenario
#  66/294: Executing NB in "Single-Model" scenario
#  67/294: Executing NB in "Single-Model" scenario
#  68/294: Executing NB in "Single-Model" scenario
#  69/294: Executing NB in "Single-Model" scenario
#  70/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  71/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  72/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  73/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  74/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  75/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  76/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  77/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  78/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  79/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  80/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  81/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  82/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  83/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  84/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  85/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  86/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  87/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  88/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  89/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  90/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  91/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  92/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  93/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  94/294: Executing Balanced-Bagging(NB) in "Ensemble-Imbalance" scenario
#  95/294: Executing NN in "Single-Model" scenario
#  96/294: Executing NN in "Single-Model" scenario
#  97/294: Executing NN in "Single-Model" scenario
#  98/294: Executing NN in "Single-Model" scenario
#  99/294: Executing NN in "Single-Model" scenario
# 100/294: Executing NN in "Single-Model" scenario
# 101/294: Executing NN in "Single-Model" scenario
# 102/294: Executing NN in "Single-Model" scenario
# 103/294: Executing NN in "Single-Model" scenario
# 104/294: Executing NN in "Single-Model" scenario
# 105/294: Executing NN in "Single-Model" scenario
# 106/294: Executing NN in "Single-Model" scenario
# 107/294: Executing NN in "Single-Model" scenario
# 108/294: Executing NN in "Single-Model" scenario
# 109/294: Executing NN in "Single-Model" scenario
# 110/294: Executing NN in "Single-Model" scenario
# 111/294: Executing NN in "Single-Model" scenario
# 112/294: Executing NN in "Single-Model" scenario
# 113/294: Executing NN in "Single-Model" scenario
# 114/294: Executing NN in "Single-Model" scenario
# 115/294: Executing NN in "Single-Model" scenario
# 116/294: Executing NN in "Single-Model" scenario
# 117/294: Executing NN in "Single-Model" scenario
# 118/294: Executing NN in "Single-Model" scenario
# 119/294: Executing NN in "Single-Model" scenario
# 120/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 121/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 122/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 123/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 124/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 125/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 126/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 127/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 128/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 129/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 130/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 131/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 132/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 133/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 134/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 135/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 136/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 137/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 138/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 139/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 140/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 141/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 142/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 143/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 144/294: Executing Balanced-Bagging(NN) in "Ensemble-Imbalance" scenario
# 145/294: Executing DT in "Single-Model" scenario
# 146/294: Executing DT in "Single-Model" scenario
# 147/294: Executing DT in "Single-Model" scenario
# 148/294: Executing DT in "Single-Model" scenario
# 149/294: Executing DT in "Single-Model" scenario
# 150/294: Executing DT in "Single-Model" scenario
# 151/294: Executing DT in "Single-Model" scenario
# 152/294: Executing DT in "Single-Model" scenario
# 153/294: Executing DT in "Single-Model" scenario
# 154/294: Executing DT in "Single-Model" scenario
# 155/294: Executing DT in "Single-Model" scenario
# 156/294: Executing DT in "Single-Model" scenario
# 157/294: Executing DT in "Single-Model" scenario
# 158/294: Executing DT in "Single-Model" scenario
# 159/294: Executing DT in "Single-Model" scenario
# 160/294: Executing DT in "Single-Model" scenario
# 161/294: Executing DT in "Single-Model" scenario
# 162/294: Executing DT in "Single-Model" scenario
# 163/294: Executing DT in "Single-Model" scenario
# 164/294: Executing DT in "Single-Model" scenario
# 165/294: Executing DT in "Single-Model" scenario
# 166/294: Executing DT in "Single-Model" scenario
# 167/294: Executing DT in "Single-Model" scenario
# 168/294: Executing DT in "Single-Model" scenario
# 169/294: Executing DT in "Single-Model" scenario
# 170/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 171/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 172/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 173/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 174/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# /home/papaiz/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py:374: UserWarning: Warm-start fitting without increasing n_estimators does not fit new trees.
#   warn(
# /home/papaiz/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py:374: UserWarning: Warm-start fitting without increasing n_estimators does not fit new trees.
#   warn(
# 175/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 176/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# /home/papaiz/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py:374: UserWarning: Warm-start fitting without increasing n_estimators does not fit new trees.
#   warn(
# 177/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 178/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# /home/papaiz/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py:374: UserWarning: Warm-start fitting without increasing n_estimators does not fit new trees.
#   warn(
# 179/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 180/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# /home/papaiz/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py:374: UserWarning: Warm-start fitting without increasing n_estimators does not fit new trees.
#   warn(
# 181/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 182/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# /home/papaiz/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py:374: UserWarning: Warm-start fitting without increasing n_estimators does not fit new trees.
#   warn(
# 183/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 184/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 185/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 186/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 187/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 188/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 189/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 190/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 191/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 192/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 193/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 194/294: Executing Balanced-Bagging(DT) in "Ensemble-Imbalance" scenario
# 195/294: Executing k-NN in "Single-Model" scenario
# 196/294: Executing k-NN in "Single-Model" scenario
# 197/294: Executing k-NN in "Single-Model" scenario
# 198/294: Executing k-NN in "Single-Model" scenario
# 199/294: Executing k-NN in "Single-Model" scenario
# 200/294: Executing k-NN in "Single-Model" scenario
# 201/294: Executing k-NN in "Single-Model" scenario
# 202/294: Executing k-NN in "Single-Model" scenario
# 203/294: Executing k-NN in "Single-Model" scenario
# 204/294: Executing k-NN in "Single-Model" scenario
# 205/294: Executing k-NN in "Single-Model" scenario
# 206/294: Executing k-NN in "Single-Model" scenario
# 207/294: Executing k-NN in "Single-Model" scenario
# 208/294: Executing k-NN in "Single-Model" scenario
# 209/294: Executing k-NN in "Single-Model" scenario
# 210/294: Executing k-NN in "Single-Model" scenario
# 211/294: Executing k-NN in "Single-Model" scenario
# 212/294: Executing k-NN in "Single-Model" scenario
# 213/294: Executing k-NN in "Single-Model" scenario
# 214/294: Executing k-NN in "Single-Model" scenario
# 215/294: Executing k-NN in "Single-Model" scenario
# 216/294: Executing k-NN in "Single-Model" scenario
# 217/294: Executing k-NN in "Single-Model" scenario
# 218/294: Executing k-NN in "Single-Model" scenario
# 219/294: Executing k-NN in "Single-Model" scenario
# 220/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 221/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 222/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 223/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 224/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 225/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 226/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 227/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 228/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 229/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 230/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 231/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 232/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 233/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 234/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 235/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 236/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 237/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 238/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 239/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 240/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 241/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 242/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 243/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 244/294: Executing Balanced-Bagging(k-NN) in "Ensemble-Imbalance" scenario
# 245/294: Executing RF in "Single-Model" scenario
# 246/294: Executing RF in "Single-Model" scenario
# 247/294: Executing RF in "Single-Model" scenario
# 248/294: Executing RF in "Single-Model" scenario
# 249/294: Executing RF in "Single-Model" scenario
# 250/294: Executing RF in "Single-Model" scenario
# 251/294: Executing RF in "Single-Model" scenario
# 252/294: Executing RF in "Single-Model" scenario
# 253/294: Executing RF in "Single-Model" scenario
# 254/294: Executing RF in "Single-Model" scenario
# 255/294: Executing RF in "Single-Model" scenario
# 256/294: Executing RF in "Single-Model" scenario
# 257/294: Executing RF in "Single-Model" scenario
# 258/294: Executing RF in "Single-Model" scenario
# 259/294: Executing RF in "Single-Model" scenario
# 260/294: Executing RF in "Single-Model" scenario
# 261/294: Executing RF in "Single-Model" scenario
# 262/294: Executing RF in "Single-Model" scenario
# 263/294: Executing RF in "Single-Model" scenario
# 264/294: Executing RF in "Single-Model" scenario
# 265/294: Executing RF in "Single-Model" scenario
# 266/294: Executing RF in "Single-Model" scenario
# 267/294: Executing RF in "Single-Model" scenario
# 268/294: Executing RF in "Single-Model" scenario
# 269/294: Executing RF in "Single-Model" scenario
# 270/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 271/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 272/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 273/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 274/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 275/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 276/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 277/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 278/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 279/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 280/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 281/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 282/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 283/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 284/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 285/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 286/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 287/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 288/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 289/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 290/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 291/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 292/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 293/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 294/294: Executing Balanced-Bagging(RF) in "Ensemble-Imbalance" scenario
# 294 samples were saved
# CPU times: user 14min 34s, sys: 5.3 s, total: 14min 40s
# Wall time: 5min 50s

# %% [markdown]
# ---
# ---
# ---
# # OTHERS

# %%
y_train[utils.CLASS_COLUMN].ravel()
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
