# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

#needed to import utils.py
sys.path.append('../') 

import utils
import numpy as np
import pandas as pd

# %matplotlib inline

# %% [markdown]
# ---
# ---
# ---
# ## Get information about the Last Visit Delta registered for each patient
# ### This information will be used to check Valid Uncensored and Censored patients

# %%
#set the data directory
data_dir = os.path.abspath('../01_raw_data/')

data_files = [
    ['PROACT_ALSFRS'    , 'ALSFRS_Delta'],
    ['PROACT_FVC'       , 'Forced_Vital_Capacity_Delta'],
    ['PROACT_DEATHDATA' , 'Death_Days'],
    ['PROACT_LABS'      , 'Laboratory_Delta'],
    ['PROACT_RILUZOLE'  , 'Riluzole_use_Delta'],
    ['PROACT_SVC'       , 'Slow_vital_Capacity_Delta'],
    ['PROACT_VITALSIGNS', 'Vital_Signs_Delta'],  
    #
    ['PROACT_ALSHISTORY',       'Subject_ALS_History_Delta'],
    ['PROACT_DEMOGRAPHICS',     'Demographics_Delta'],
    ['PROACT_ELESCORIAL',       'delta_days'],
    ['PROACT_FAMILYHISTORY',    'Family_History_Delta'],
    ['PROACT_HANDGRIPSTRENGTH', 'MS_Delta'],
    ['PROACT_MUSCLESTRENGTH',   'MS_Delta'],
    ['PROACT_TREATMENT',        'Treatment_Group_Delta'],
    #start and end deltas
    ['PROACT_ADVERSEEVENTS',    'Start_Date_Delta'], #
    ['PROACT_ADVERSEEVENTS',    'End_Date_Delta'], #Start_Date_Delta
    ['PROACT_CONMEDS',          'Start_Delta'], #,
    ['PROACT_CONMEDS',          'Stop_Delta'], #Start_Delta,

]




df_last_visit = pd.DataFrame(data=[], columns=['subject_id', 'Delta', 'Biomarker'])

for data_file, col_delta in data_files:
    print(data_file, ' - ', col_delta)
    #set the name of CSV file
    csv_file = f'{data_dir}/{data_file}.csv'

    #read data and show some info
    df_raw = pd.read_csv(csv_file, 
                         delimiter=',', 
                         usecols=['subject_id', col_delta] #read only columns subject_id and delta
                        )
    
    
    #rename column Delta to standardize
    df_raw.rename(columns={col_delta: "Last_Visit_Delta"}, inplace=True)

    #sort data by subject_d and Delta in ascending order    
    df_raw.sort_values(['subject_id', 'Last_Visit_Delta'])
    
    #group by subject_id and get max Delta for each of them
    df_grouped = df_raw.groupby('subject_id').max()
    #reset index to re-organize columns index (solve problem of subject_id become the index of the DF)
    df_grouped.reset_index(inplace=True)
    
    #create column to represent the biomarker source of information
    df_grouped['Biomarker'] = data_file
    
    #concatenate data into "df_last_visit" dataFrame
    if df_last_visit.shape[0]==0:
        df_last_visit = df_grouped.copy()
    else:   
        df_last_visit = pd.concat([df_last_visit, df_grouped], ignore_index=True)


#drop rows with NaN values    
df_last_visit.dropna(inplace=True)    

#sort data by subject_d and Delta in ascending order    
df_last_visit.sort_values(['subject_id', 'Last_Visit_Delta'])

#group by subject_id and get max Delta for each of them
df_last_visit = df_last_visit.groupby('subject_id').max()
df_last_visit.reset_index(inplace=True)


df_last_visit
# Out:
# PROACT_ALSFRS  -  ALSFRS_Delta
# PROACT_FVC  -  Forced_Vital_Capacity_Delta
# PROACT_DEATHDATA  -  Death_Days
# PROACT_LABS  -  Laboratory_Delta
# PROACT_RILUZOLE  -  Riluzole_use_Delta
# PROACT_SVC  -  Slow_vital_Capacity_Delta
# PROACT_VITALSIGNS  -  Vital_Signs_Delta
# PROACT_ALSHISTORY  -  Subject_ALS_History_Delta
# PROACT_DEMOGRAPHICS  -  Demographics_Delta
# PROACT_ELESCORIAL  -  delta_days
# PROACT_FAMILYHISTORY  -  Family_History_Delta
# PROACT_HANDGRIPSTRENGTH  -  MS_Delta
# PROACT_MUSCLESTRENGTH  -  MS_Delta
# PROACT_TREATMENT  -  Treatment_Group_Delta
# PROACT_ADVERSEEVENTS  -  Start_Date_Delta
# PROACT_ADVERSEEVENTS  -  End_Date_Delta
# PROACT_CONMEDS  -  Start_Delta
# PROACT_CONMEDS  -  Stop_Delta
#        subject_id  Last_Visit_Delta          Biomarker
# 0              89             218.0    PROACT_RILUZOLE
# 1             329             287.0  PROACT_VITALSIGNS
# 2             348             401.0  PROACT_VITALSIGNS
# 3             406             288.0    PROACT_RILUZOLE
# 4             411             141.0    PROACT_RILUZOLE
# ...           ...               ...                ...
# 11669      999823             185.0  PROACT_VITALSIGNS
# 11670      999863             267.0    PROACT_RILUZOLE
# 11671      999880             266.0  PROACT_VITALSIGNS
# 11672      999929             168.0  PROACT_VITALSIGNS
# 11673      999990             126.0  PROACT_VITALSIGNS
#
# [11674 rows x 3 columns]

# %% [markdown]
# ---
# ---
# ---
# ## Read data from `Pre-processed` (demographics + ALS History) csv file

# %%
#set the data directory
data_dir = os.path.abspath('../03_preprocessed_data/')

#set the name of CSV file
data_file = f'{data_dir}/_patient.csv'

#read data and show some info
df_main = pd.read_csv(data_file, delimiter=',')
df_main
# Out:
#       subject_id     Sex  Qty_Measurements_ALSFRS  \
# 0            329  Female                     12.0
# 1            348  Female                     15.0
# 2            533  Female                      6.0
# 3            586    Male                      1.0
# 4            708    Male                     11.0
# ...          ...     ...                      ...
# 5225       22564    Male                      7.0
# 5226      160135  Female                      7.0
# 5227      304192  Female                      7.0
# 5228      820199    Male                      7.0
# 5229      587563  Female                      6.0
#
#       Qty_Measurements_VITALSIGNS  Qty_Measurements_FVC  Qty_Measurements_SVC  \
# 0                            13.0                   8.0                   0.0
# 1                            10.0                   0.0                   9.0
# 2                            10.0                   2.0                   6.0
# 3                             1.0                   1.0                   0.0
# 4                            12.0                   7.0                   0.0
# ...                           ...                   ...                   ...
# 5225                          0.0                   0.0                   7.0
# 5226                          0.0                   0.0                   6.0
# 5227                          0.0                   0.0                   7.0
# 5228                          0.0                   0.0                   7.0
# 5229                          0.0                   0.0                   4.0
#
#       Qty_Measurements_LABS  Qty_Measurements_HANDGRIPSTRENGTH  \
# 0                     465.0                                0.0
# 1                     820.0                                0.0
# 2                     126.0                                0.0
# 3                       0.0                                0.0
# 4                     404.0                                0.0
# ...                     ...                                ...
# 5225                  376.0                               14.0
# 5226                  365.0                               14.0
# 5227                  365.0                               14.0
# 5228                  363.0                               14.0
# 5229                  263.0                                8.0
#
#       Qty_Measurements_MUSCLESTRENGTH  Qty_Measurements  Symptoms_Onset_Delta  \
# 0                                 0.0             498.0               -1706.0
# 1                                 0.0             854.0                -501.0
# 2                                 0.0             150.0               -1023.0
# 3                                 0.0               3.0                -715.0
# 4                                 0.0             434.0               -1070.0
# ...                               ...               ...                   ...
# 5225                            201.0             605.0                -426.0
# 5226                            189.0             581.0                -651.0
# 5227                            168.0             561.0                -838.0
# 5228                            173.0             564.0                -155.0
# 5229                            101.0             382.0                -580.0
#
#       Diagnosis_Delta   Site_Onset  Diagnosis_Delay Diagnosis_Delay_Str  \
# 0             -1068.0  Limb/Spinal             21.0               Short
# 1              -302.0        Other              6.0                Long
# 2               -44.0       Bulbar             32.0               Short
# 3              -507.0       Bulbar              6.0                Long
# 4              -986.0       Bulbar              2.0                Long
# ...               ...          ...              ...                 ...
# 5225            -67.0  Limb/Spinal             11.0             Average
# 5226           -125.0       Bulbar             17.0             Average
# 5227           -351.0  Limb/Spinal             16.0             Average
# 5228            -35.0  Limb/Spinal              4.0                Long
# 5229           -264.0       Bulbar             10.0             Average
#
#       Diagnosis_Delay_Coded  Age_at_Onset Age_Range_at_Onset  \
# 0                       0.0          34.0               0-39
# 1                       2.0          51.0              50-59
# 2                       0.0          63.0              60-69
# 3                       2.0          61.0              60-69
# 4                       2.0          43.0              40-49
# ...                     ...           ...                ...
# 5225                    1.0          62.0              60-69
# 5226                    1.0          66.0              60-69
# 5227                    1.0          57.0              50-59
# 5228                    2.0          49.0              40-49
# 5229                    1.0          72.0                70+
#
#       Age_Range_at_Onset_Coded
# 0                          0.0
# 1                          2.0
# 2                          3.0
# 3                          3.0
# 4                          1.0
# ...                        ...
# 5225                       3.0
# 5226                       3.0
# 5227                       2.0
# 5228                       1.0
# 5229                       4.0
#
# [5230 rows x 19 columns]

# %% [markdown]
# ---
# ---
# ---
# ## Join the `Patients` and `Last_Visit` dataFrames

# %%
df_to_join = df_last_visit[['subject_id', 'Last_Visit_Delta']].copy()

df_main = utils.join_datasets_by_key(df_main=df_main, 
                                df_to_join=df_to_join, 
                                key_name='subject_id', 
                                how='left')

df_main
# Out:
#       subject_id     Sex  Qty_Measurements_ALSFRS  \
# 0            329  Female                     12.0
# 1            348  Female                     15.0
# 2            533  Female                      6.0
# 3            586    Male                      1.0
# 4            708    Male                     11.0
# ...          ...     ...                      ...
# 5225       22564    Male                      7.0
# 5226      160135  Female                      7.0
# 5227      304192  Female                      7.0
# 5228      820199    Male                      7.0
# 5229      587563  Female                      6.0
#
#       Qty_Measurements_VITALSIGNS  Qty_Measurements_FVC  Qty_Measurements_SVC  \
# 0                            13.0                   8.0                   0.0
# 1                            10.0                   0.0                   9.0
# 2                            10.0                   2.0                   6.0
# 3                             1.0                   1.0                   0.0
# 4                            12.0                   7.0                   0.0
# ...                           ...                   ...                   ...
# 5225                          0.0                   0.0                   7.0
# 5226                          0.0                   0.0                   6.0
# 5227                          0.0                   0.0                   7.0
# 5228                          0.0                   0.0                   7.0
# 5229                          0.0                   0.0                   4.0
#
#       Qty_Measurements_LABS  Qty_Measurements_HANDGRIPSTRENGTH  \
# 0                     465.0                                0.0
# 1                     820.0                                0.0
# 2                     126.0                                0.0
# 3                       0.0                                0.0
# 4                     404.0                                0.0
# ...                     ...                                ...
# 5225                  376.0                               14.0
# 5226                  365.0                               14.0
# 5227                  365.0                               14.0
# 5228                  363.0                               14.0
# 5229                  263.0                                8.0
#
#       Qty_Measurements_MUSCLESTRENGTH  Qty_Measurements  Symptoms_Onset_Delta  \
# 0                                 0.0             498.0               -1706.0
# 1                                 0.0             854.0                -501.0
# 2                                 0.0             150.0               -1023.0
# 3                                 0.0               3.0                -715.0
# 4                                 0.0             434.0               -1070.0
# ...                               ...               ...                   ...
# 5225                            201.0             605.0                -426.0
# 5226                            189.0             581.0                -651.0
# 5227                            168.0             561.0                -838.0
# 5228                            173.0             564.0                -155.0
# 5229                            101.0             382.0                -580.0
#
#       Diagnosis_Delta   Site_Onset  Diagnosis_Delay Diagnosis_Delay_Str  \
# 0             -1068.0  Limb/Spinal             21.0               Short
# 1              -302.0        Other              6.0                Long
# 2               -44.0       Bulbar             32.0               Short
# 3              -507.0       Bulbar              6.0                Long
# 4              -986.0       Bulbar              2.0                Long
# ...               ...          ...              ...                 ...
# 5225            -67.0  Limb/Spinal             11.0             Average
# 5226           -125.0       Bulbar             17.0             Average
# 5227           -351.0  Limb/Spinal             16.0             Average
# 5228            -35.0  Limb/Spinal              4.0                Long
# 5229           -264.0       Bulbar             10.0             Average
#
#       Diagnosis_Delay_Coded  Age_at_Onset Age_Range_at_Onset  \
# 0                       0.0          34.0               0-39
# 1                       2.0          51.0              50-59
# 2                       0.0          63.0              60-69
# 3                       2.0          61.0              60-69
# 4                       2.0          43.0              40-49
# ...                     ...           ...                ...
# 5225                    1.0          62.0              60-69
# 5226                    1.0          66.0              60-69
# 5227                    1.0          57.0              50-59
# 5228                    2.0          49.0              40-49
# 5229                    1.0          72.0                70+
#
#       Age_Range_at_Onset_Coded  Last_Visit_Delta
# 0                          0.0             287.0
# 1                          2.0             401.0
# 2                          3.0             404.0
# 3                          3.0               3.0
# 4                          1.0             250.0
# ...                        ...               ...
# 5225                       3.0             119.0
# 5226                       3.0             127.0
# 5227                       2.0             127.0
# 5228                       1.0             125.0
# 5229                       4.0              99.0
#
# [5230 rows x 20 columns]

# %% [markdown]
# ### Calculate Last Visit in days and months from `symptoms onset`

# %%
df_main['Last_Visit_from_Onset_in_Days'] = np.abs(df_main.Last_Visit_Delta) + np.abs(df_main.Symptoms_Onset_Delta)

last_visit = df_main['Last_Visit_from_Onset_in_Days'].apply( lambda x: utils.calculate_months_from_days(x)) 

df_main.loc[df_main.index,'Last_Visit_from_Onset'] = last_visit

display(df_main)

utils.show_columns_stats(df_main)
# Out:
#       subject_id     Sex  Qty_Measurements_ALSFRS  \
# 0            329  Female                     12.0
# 1            348  Female                     15.0
# 2            533  Female                      6.0
# 3            586    Male                      1.0
# 4            708    Male                     11.0
# ...          ...     ...                      ...
# 5225       22564    Male                      7.0
# 5226      160135  Female                      7.0
# 5227      304192  Female                      7.0
# 5228      820199    Male                      7.0
# 5229      587563  Female                      6.0
#
#       Qty_Measurements_VITALSIGNS  Qty_Measurements_FVC  Qty_Measurements_SVC  \
# 0                            13.0                   8.0                   0.0
# 1                            10.0                   0.0                   9.0
# 2                            10.0                   2.0                   6.0
# 3                             1.0                   1.0                   0.0
# 4                            12.0                   7.0                   0.0
# ...                           ...                   ...                   ...
# 5225                          0.0                   0.0                   7.0
# 5226                          0.0                   0.0                   6.0
# 5227                          0.0                   0.0                   7.0
# 5228                          0.0                   0.0                   7.0
# 5229                          0.0                   0.0                   4.0
#
#       Qty_Measurements_LABS  Qty_Measurements_HANDGRIPSTRENGTH  \
# 0                     465.0                                0.0
# 1                     820.0                                0.0
# 2                     126.0                                0.0
# 3                       0.0                                0.0
# 4                     404.0                                0.0
# ...                     ...                                ...
# 5225                  376.0                               14.0
# 5226                  365.0                               14.0
# 5227                  365.0                               14.0
# 5228                  363.0                               14.0
# 5229                  263.0                                8.0
#
#       Qty_Measurements_MUSCLESTRENGTH  Qty_Measurements  ...   Site_Onset  \
# 0                                 0.0             498.0  ...  Limb/Spinal
# 1                                 0.0             854.0  ...        Other
# 2                                 0.0             150.0  ...       Bulbar
# 3                                 0.0               3.0  ...       Bulbar
# 4                                 0.0             434.0  ...       Bulbar
# ...                               ...               ...  ...          ...
# 5225                            201.0             605.0  ...  Limb/Spinal
# 5226                            189.0             581.0  ...       Bulbar
# 5227                            168.0             561.0  ...  Limb/Spinal
# 5228                            173.0             564.0  ...  Limb/Spinal
# 5229                            101.0             382.0  ...       Bulbar
#
#       Diagnosis_Delay Diagnosis_Delay_Str  Diagnosis_Delay_Coded Age_at_Onset  \
# 0                21.0               Short                    0.0         34.0
# 1                 6.0                Long                    2.0         51.0
# 2                32.0               Short                    0.0         63.0
# 3                 6.0                Long                    2.0         61.0
# 4                 2.0                Long                    2.0         43.0
# ...               ...                 ...                    ...          ...
# 5225             11.0             Average                    1.0         62.0
# 5226             17.0             Average                    1.0         66.0
# 5227             16.0             Average                    1.0         57.0
# 5228              4.0                Long                    2.0         49.0
# 5229             10.0             Average                    1.0         72.0
#
#       Age_Range_at_Onset  Age_Range_at_Onset_Coded Last_Visit_Delta  \
# 0                   0-39                       0.0            287.0
# 1                  50-59                       2.0            401.0
# 2                  60-69                       3.0            404.0
# 3                  60-69                       3.0              3.0
# 4                  40-49                       1.0            250.0
# ...                  ...                       ...              ...
# 5225               60-69                       3.0            119.0
# 5226               60-69                       3.0            127.0
# 5227               50-59                       2.0            127.0
# 5228               40-49                       1.0            125.0
# 5229                 70+                       4.0             99.0
#
#       Last_Visit_from_Onset_in_Days  Last_Visit_from_Onset
# 0                            1993.0                     65
# 1                             902.0                     29
# 2                            1427.0                     46
# 3                             718.0                     23
# 4                            1320.0                     43
# ...                             ...                    ...
# 5225                          545.0                     17
# 5226                          778.0                     25
# 5227                          965.0                     31
# 5228                          280.0                      9
# 5229                          679.0                     22
#
# [5230 rows x 22 columns]
# subject_id....................... =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=  5230
# Sex.............................. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=     2
# Qty_Measurements_ALSFRS.......... =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=    32
# Qty_Measurements_VITALSIGNS...... =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=    55
# Qty_Measurements_FVC............. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=    20
# Qty_Measurements_SVC............. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=    17
# Qty_Measurements_LABS............ =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=   953
# Qty_Measurements_HANDGRIPSTRENGTH =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=    38
# Qty_Measurements_MUSCLESTRENGTH.. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=   293
# Qty_Measurements................. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=  1087
# Symptoms_Onset_Delta............. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=  1317
# Diagnosis_Delta.................. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=   960
# Site_Onset....................... =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=     4
# Diagnosis_Delay.................. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=    69
# Diagnosis_Delay_Str.............. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=     3
# Diagnosis_Delay_Coded............ =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=     3
# Age_at_Onset..................... =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=    68
# Age_Range_at_Onset............... =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=     5
# Age_Range_at_Onset_Coded......... =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=     5
# Last_Visit_Delta................. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=   837
# Last_Visit_from_Onset_in_Days.... =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=  1551
# Last_Visit_from_Onset............ =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=   111

# %% [markdown]
# ---
# ---
# ---
# ## Read `DeathData` CSV file and show some stats

# %%
#set the data directory
data_dir = os.path.abspath('../01_raw_data/')

#set the name of CSV file
data_file = f'{data_dir}/PROACT_DEATHDATA.csv'

#read data and show some info
df_raw = pd.read_csv(data_file, delimiter=',')

utils.show_columns_stats(df_raw)
# Out:
# subject_id.. =  4875 rows (100.0%)     0 with NaN (  0.0%) Uniques=  4874
# Subject_Died =  4875 rows (100.0%)     0 with NaN (  0.0%) Uniques=     2
# Death_Days.. =  3432 rows ( 70.4%)  1443 with NaN ( 29.6%) Uniques=   721

# %% [markdown]
# ### Join the 2 datasets (renaming some columns)

# %%
df = utils.join_datasets_by_key(df_main=df_main, df_to_join=df_raw, key_name='subject_id', how='left', 
                                raise_error=True)

# rename columns
df.rename(
    columns={
        "Subject_Died": "Event_Dead", 
        "Death_Days": "Event_Dead_Delta"
    }, 
    inplace=True
)

print(utils.get_quantity_of_rows(df_main))
print(utils.get_quantity_of_rows(df_raw))
print(utils.get_quantity_of_rows(df))

df
# Out:
# 5230
# 4875
# 5230
#       subject_id     Sex  Qty_Measurements_ALSFRS  \
# 0            329  Female                     12.0
# 1            348  Female                     15.0
# 2            533  Female                      6.0
# 3            586    Male                      1.0
# 4            708    Male                     11.0
# ...          ...     ...                      ...
# 5225       22564    Male                      7.0
# 5226      160135  Female                      7.0
# 5227      304192  Female                      7.0
# 5228      820199    Male                      7.0
# 5229      587563  Female                      6.0
#
#       Qty_Measurements_VITALSIGNS  Qty_Measurements_FVC  Qty_Measurements_SVC  \
# 0                            13.0                   8.0                   0.0
# 1                            10.0                   0.0                   9.0
# 2                            10.0                   2.0                   6.0
# 3                             1.0                   1.0                   0.0
# 4                            12.0                   7.0                   0.0
# ...                           ...                   ...                   ...
# 5225                          0.0                   0.0                   7.0
# 5226                          0.0                   0.0                   6.0
# 5227                          0.0                   0.0                   7.0
# 5228                          0.0                   0.0                   7.0
# 5229                          0.0                   0.0                   4.0
#
#       Qty_Measurements_LABS  Qty_Measurements_HANDGRIPSTRENGTH  \
# 0                     465.0                                0.0
# 1                     820.0                                0.0
# 2                     126.0                                0.0
# 3                       0.0                                0.0
# 4                     404.0                                0.0
# ...                     ...                                ...
# 5225                  376.0                               14.0
# 5226                  365.0                               14.0
# 5227                  365.0                               14.0
# 5228                  363.0                               14.0
# 5229                  263.0                                8.0
#
#       Qty_Measurements_MUSCLESTRENGTH  Qty_Measurements  ...  \
# 0                                 0.0             498.0  ...
# 1                                 0.0             854.0  ...
# 2                                 0.0             150.0  ...
# 3                                 0.0               3.0  ...
# 4                                 0.0             434.0  ...
# ...                               ...               ...  ...
# 5225                            201.0             605.0  ...
# 5226                            189.0             581.0  ...
# 5227                            168.0             561.0  ...
# 5228                            173.0             564.0  ...
# 5229                            101.0             382.0  ...
#
#       Diagnosis_Delay_Str  Diagnosis_Delay_Coded Age_at_Onset  \
# 0                   Short                    0.0         34.0
# 1                    Long                    2.0         51.0
# 2                   Short                    0.0         63.0
# 3                    Long                    2.0         61.0
# 4                    Long                    2.0         43.0
# ...                   ...                    ...          ...
# 5225              Average                    1.0         62.0
# 5226              Average                    1.0         66.0
# 5227              Average                    1.0         57.0
# 5228                 Long                    2.0         49.0
# 5229              Average                    1.0         72.0
#
#       Age_Range_at_Onset Age_Range_at_Onset_Coded  Last_Visit_Delta  \
# 0                   0-39                      0.0             287.0
# 1                  50-59                      2.0             401.0
# 2                  60-69                      3.0             404.0
# 3                  60-69                      3.0               3.0
# 4                  40-49                      1.0             250.0
# ...                  ...                      ...               ...
# 5225               60-69                      3.0             119.0
# 5226               60-69                      3.0             127.0
# 5227               50-59                      2.0             127.0
# 5228               40-49                      1.0             125.0
# 5229                 70+                      4.0              99.0
#
#       Last_Visit_from_Onset_in_Days Last_Visit_from_Onset  Event_Dead  \
# 0                            1993.0                    65         NaN
# 1                             902.0                    29         NaN
# 2                            1427.0                    46         NaN
# 3                             718.0                    23         NaN
# 4                            1320.0                    43         Yes
# ...                             ...                   ...         ...
# 5225                          545.0                    17         NaN
# 5226                          778.0                    25         NaN
# 5227                          965.0                    31         NaN
# 5228                          280.0                     9         NaN
# 5229                          679.0                    22         NaN
#
#       Event_Dead_Delta
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                250.0
# ...                ...
# 5225               NaN
# 5226               NaN
# 5227               NaN
# 5228               NaN
# 5229               NaN
#
# [5230 rows x 24 columns]

# %% [markdown]
# ---
# ---
# ---
# ## Convert `event_dead` column to `Boolean` datatype, converting `NaN` values to False (not dead)

# %%
df.groupby('Event_Dead', dropna=False).count()
# Out:
#             subject_id   Sex  Qty_Measurements_ALSFRS  \
# Event_Dead
# No                1171  1171                     1171
# Yes               1250  1250                     1250
# NaN               2809  2809                     2809
#
#             Qty_Measurements_VITALSIGNS  Qty_Measurements_FVC  \
# Event_Dead
# No                                 1171                  1171
# Yes                                1250                  1250
# NaN                                2809                  2809
#
#             Qty_Measurements_SVC  Qty_Measurements_LABS  \
# Event_Dead
# No                          1171                   1171
# Yes                         1250                   1250
# NaN                         2809                   2809
#
#             Qty_Measurements_HANDGRIPSTRENGTH  \
# Event_Dead
# No                                       1171
# Yes                                      1250
# NaN                                      2809
#
#             Qty_Measurements_MUSCLESTRENGTH  Qty_Measurements  ...  \
# Event_Dead                                                     ...
# No                                     1171              1171  ...
# Yes                                    1250              1250  ...
# NaN                                    2809              2809  ...
#
#             Diagnosis_Delay  Diagnosis_Delay_Str  Diagnosis_Delay_Coded  \
# Event_Dead
# No                     1171                 1171                   1171
# Yes                    1250                 1250                   1250
# NaN                    2809                 2809                   2809
#
#             Age_at_Onset  Age_Range_at_Onset  Age_Range_at_Onset_Coded  \
# Event_Dead
# No                  1171                1171                      1171
# Yes                 1250                1250                      1250
# NaN                 2809                2809                      2809
#
#             Last_Visit_Delta  Last_Visit_from_Onset_in_Days  \
# Event_Dead
# No                      1171                           1171
# Yes                     1250                           1250
# NaN                     2809                           2809
#
#             Last_Visit_from_Onset  Event_Dead_Delta
# Event_Dead
# No                           1171                 0
# Yes                          1250              1084
# NaN                          2809                 0
#
# [3 rows x 23 columns]

# %%
df.Event_Dead = df.Event_Dead.map(
    {
        'Yes'  : True,
        'No'   : False, 
         np.NaN: False,
    }
)

df
# Out:
#       subject_id     Sex  Qty_Measurements_ALSFRS  \
# 0            329  Female                     12.0
# 1            348  Female                     15.0
# 2            533  Female                      6.0
# 3            586    Male                      1.0
# 4            708    Male                     11.0
# ...          ...     ...                      ...
# 5225       22564    Male                      7.0
# 5226      160135  Female                      7.0
# 5227      304192  Female                      7.0
# 5228      820199    Male                      7.0
# 5229      587563  Female                      6.0
#
#       Qty_Measurements_VITALSIGNS  Qty_Measurements_FVC  Qty_Measurements_SVC  \
# 0                            13.0                   8.0                   0.0
# 1                            10.0                   0.0                   9.0
# 2                            10.0                   2.0                   6.0
# 3                             1.0                   1.0                   0.0
# 4                            12.0                   7.0                   0.0
# ...                           ...                   ...                   ...
# 5225                          0.0                   0.0                   7.0
# 5226                          0.0                   0.0                   6.0
# 5227                          0.0                   0.0                   7.0
# 5228                          0.0                   0.0                   7.0
# 5229                          0.0                   0.0                   4.0
#
#       Qty_Measurements_LABS  Qty_Measurements_HANDGRIPSTRENGTH  \
# 0                     465.0                                0.0
# 1                     820.0                                0.0
# 2                     126.0                                0.0
# 3                       0.0                                0.0
# 4                     404.0                                0.0
# ...                     ...                                ...
# 5225                  376.0                               14.0
# 5226                  365.0                               14.0
# 5227                  365.0                               14.0
# 5228                  363.0                               14.0
# 5229                  263.0                                8.0
#
#       Qty_Measurements_MUSCLESTRENGTH  Qty_Measurements  ...  \
# 0                                 0.0             498.0  ...
# 1                                 0.0             854.0  ...
# 2                                 0.0             150.0  ...
# 3                                 0.0               3.0  ...
# 4                                 0.0             434.0  ...
# ...                               ...               ...  ...
# 5225                            201.0             605.0  ...
# 5226                            189.0             581.0  ...
# 5227                            168.0             561.0  ...
# 5228                            173.0             564.0  ...
# 5229                            101.0             382.0  ...
#
#       Diagnosis_Delay_Str  Diagnosis_Delay_Coded Age_at_Onset  \
# 0                   Short                    0.0         34.0
# 1                    Long                    2.0         51.0
# 2                   Short                    0.0         63.0
# 3                    Long                    2.0         61.0
# 4                    Long                    2.0         43.0
# ...                   ...                    ...          ...
# 5225              Average                    1.0         62.0
# 5226              Average                    1.0         66.0
# 5227              Average                    1.0         57.0
# 5228                 Long                    2.0         49.0
# 5229              Average                    1.0         72.0
#
#       Age_Range_at_Onset Age_Range_at_Onset_Coded  Last_Visit_Delta  \
# 0                   0-39                      0.0             287.0
# 1                  50-59                      2.0             401.0
# 2                  60-69                      3.0             404.0
# 3                  60-69                      3.0               3.0
# 4                  40-49                      1.0             250.0
# ...                  ...                      ...               ...
# 5225               60-69                      3.0             119.0
# 5226               60-69                      3.0             127.0
# 5227               50-59                      2.0             127.0
# 5228               40-49                      1.0             125.0
# 5229                 70+                      4.0              99.0
#
#       Last_Visit_from_Onset_in_Days Last_Visit_from_Onset  Event_Dead  \
# 0                            1993.0                    65       False
# 1                             902.0                    29       False
# 2                            1427.0                    46       False
# 3                             718.0                    23       False
# 4                            1320.0                    43        True
# ...                             ...                   ...         ...
# 5225                          545.0                    17       False
# 5226                          778.0                    25       False
# 5227                          965.0                    31       False
# 5228                          280.0                     9       False
# 5229                          679.0                    22       False
#
#       Event_Dead_Delta
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                250.0
# ...                ...
# 5225               NaN
# 5226               NaN
# 5227               NaN
# 5228               NaN
# 5229               NaN
#
# [5230 rows x 24 columns]

# %% [markdown]
# ### Create column `Event_Dead_Delta_from_Onset_in_days` with
# ### the `Last_Visit_Delta_from_Onset_in_days` column for those samples with
# ### `Event_Dead` = `False` (not died)

# %%
df_event_dead_false = df.loc[(df.Event_Dead==False)].copy()

df_event_dead_false['Event_Dead_Time_from_Onset_in_days'] = df_event_dead_false['Last_Visit_from_Onset_in_Days']
df_event_dead_false['Event_Dead_Time_from_Onset'] = df_event_dead_false['Last_Visit_from_Onset']


df.loc[df_event_dead_false.index,
      'Event_Dead_Time_from_Onset_in_days'] = df_event_dead_false['Event_Dead_Time_from_Onset_in_days']

df.loc[df_event_dead_false.index,
      'Event_Dead_Time_from_Onset'] = df_event_dead_false['Event_Dead_Time_from_Onset']

df
# Out:
#       subject_id     Sex  Qty_Measurements_ALSFRS  \
# 0            329  Female                     12.0
# 1            348  Female                     15.0
# 2            533  Female                      6.0
# 3            586    Male                      1.0
# 4            708    Male                     11.0
# ...          ...     ...                      ...
# 5225       22564    Male                      7.0
# 5226      160135  Female                      7.0
# 5227      304192  Female                      7.0
# 5228      820199    Male                      7.0
# 5229      587563  Female                      6.0
#
#       Qty_Measurements_VITALSIGNS  Qty_Measurements_FVC  Qty_Measurements_SVC  \
# 0                            13.0                   8.0                   0.0
# 1                            10.0                   0.0                   9.0
# 2                            10.0                   2.0                   6.0
# 3                             1.0                   1.0                   0.0
# 4                            12.0                   7.0                   0.0
# ...                           ...                   ...                   ...
# 5225                          0.0                   0.0                   7.0
# 5226                          0.0                   0.0                   6.0
# 5227                          0.0                   0.0                   7.0
# 5228                          0.0                   0.0                   7.0
# 5229                          0.0                   0.0                   4.0
#
#       Qty_Measurements_LABS  Qty_Measurements_HANDGRIPSTRENGTH  \
# 0                     465.0                                0.0
# 1                     820.0                                0.0
# 2                     126.0                                0.0
# 3                       0.0                                0.0
# 4                     404.0                                0.0
# ...                     ...                                ...
# 5225                  376.0                               14.0
# 5226                  365.0                               14.0
# 5227                  365.0                               14.0
# 5228                  363.0                               14.0
# 5229                  263.0                                8.0
#
#       Qty_Measurements_MUSCLESTRENGTH  Qty_Measurements  ...  Age_at_Onset  \
# 0                                 0.0             498.0  ...          34.0
# 1                                 0.0             854.0  ...          51.0
# 2                                 0.0             150.0  ...          63.0
# 3                                 0.0               3.0  ...          61.0
# 4                                 0.0             434.0  ...          43.0
# ...                               ...               ...  ...           ...
# 5225                            201.0             605.0  ...          62.0
# 5226                            189.0             581.0  ...          66.0
# 5227                            168.0             561.0  ...          57.0
# 5228                            173.0             564.0  ...          49.0
# 5229                            101.0             382.0  ...          72.0
#
#       Age_Range_at_Onset Age_Range_at_Onset_Coded  Last_Visit_Delta  \
# 0                   0-39                      0.0             287.0
# 1                  50-59                      2.0             401.0
# 2                  60-69                      3.0             404.0
# 3                  60-69                      3.0               3.0
# 4                  40-49                      1.0             250.0
# ...                  ...                      ...               ...
# 5225               60-69                      3.0             119.0
# 5226               60-69                      3.0             127.0
# 5227               50-59                      2.0             127.0
# 5228               40-49                      1.0             125.0
# 5229                 70+                      4.0              99.0
#
#      Last_Visit_from_Onset_in_Days  Last_Visit_from_Onset  Event_Dead  \
# 0                           1993.0                     65       False
# 1                            902.0                     29       False
# 2                           1427.0                     46       False
# 3                            718.0                     23       False
# 4                           1320.0                     43        True
# ...                            ...                    ...         ...
# 5225                         545.0                     17       False
# 5226                         778.0                     25       False
# 5227                         965.0                     31       False
# 5228                         280.0                      9       False
# 5229                         679.0                     22       False
#
#      Event_Dead_Delta  Event_Dead_Time_from_Onset_in_days  \
# 0                 NaN                              1993.0
# 1                 NaN                               902.0
# 2                 NaN                              1427.0
# 3                 NaN                               718.0
# 4               250.0                                 NaN
# ...               ...                                 ...
# 5225              NaN                               545.0
# 5226              NaN                               778.0
# 5227              NaN                               965.0
# 5228              NaN                               280.0
# 5229              NaN                               679.0
#
#       Event_Dead_Time_from_Onset
# 0                           65.0
# 1                           29.0
# 2                           46.0
# 3                           23.0
# 4                            NaN
# ...                          ...
# 5225                        17.0
# 5226                        25.0
# 5227                        31.0
# 5228                         9.0
# 5229                        22.0
#
# [5230 rows x 26 columns]

# %% [markdown]
# ### Check if exist NaN-values (must print `[False  True]`)

# %%
#check if exist NaN-values (must show [False  True])
print(df.Event_Dead_Time_from_Onset.isna().unique())
# Out:
# [False  True]

# %% [markdown]
# ### Create column `Event_Dead_Delta_from_Onset_in_days` with
# ### the `Last_Visit_Delta_from_Onset_in_days` column for those samples with `Event_Dead` = `True` (died)
# ### and  `Event_Dead_Delta` = NaN

# %%
df_event_dead_true = df.loc[
    (df.Event_Dead==True)
   &(df.Event_Dead_Delta.isnull() )
].copy()

display(df_event_dead_true)

df.loc[df_event_dead_true.index,
      'Event_Dead_Time_from_Onset_in_days'] = df['Last_Visit_from_Onset_in_Days']

df.loc[df_event_dead_true.index,
      'Event_Dead_Time_from_Onset'] = df['Last_Visit_from_Onset']

df.loc[df_event_dead_true.index]
# Out:
#       subject_id     Sex  Qty_Measurements_ALSFRS  \
# 16          4205    Male                      5.0
# 17          4429    Male                      4.0
# 23          5148    Male                      2.0
# 27          5806  Female                      4.0
# 95         16265  Female                      4.0
# ...          ...     ...                      ...
# 4566      960114  Female                      3.0
# 4650      975460    Male                      1.0
# 4737      993802    Male                      5.0
# 4765      999117    Male                      4.0
# 4770      999929    Male                      3.0
#
#       Qty_Measurements_VITALSIGNS  Qty_Measurements_FVC  Qty_Measurements_SVC  \
# 16                            5.0                   0.0                   0.0
# 17                            4.0                   0.0                   0.0
# 23                            2.0                   0.0                   0.0
# 27                            4.0                   0.0                   0.0
# 95                            4.0                   0.0                   0.0
# ...                           ...                   ...                   ...
# 4566                          3.0                   0.0                   0.0
# 4650                          1.0                   0.0                   0.0
# 4737                          5.0                   0.0                   0.0
# 4765                          4.0                   0.0                   0.0
# 4770                          3.0                   0.0                   0.0
#
#       Qty_Measurements_LABS  Qty_Measurements_HANDGRIPSTRENGTH  \
# 16                     20.0                                0.0
# 17                     16.0                                0.0
# 23                      8.0                                0.0
# 27                     16.0                                0.0
# 95                     16.0                                0.0
# ...                     ...                                ...
# 4566                   12.0                                0.0
# 4650                    4.0                                0.0
# 4737                   20.0                                0.0
# 4765                   16.0                                0.0
# 4770                   12.0                                0.0
#
#       Qty_Measurements_MUSCLESTRENGTH  Qty_Measurements  ...  Age_at_Onset  \
# 16                                0.0              30.0  ...          38.0
# 17                                0.0              24.0  ...          56.0
# 23                                0.0              12.0  ...          65.0
# 27                                0.0              24.0  ...          69.0
# 95                                0.0              24.0  ...          63.0
# ...                               ...               ...  ...           ...
# 4566                              0.0              18.0  ...          62.0
# 4650                              0.0               6.0  ...          78.0
# 4737                              0.0              30.0  ...          53.0
# 4765                              0.0              24.0  ...          54.0
# 4770                              0.0              18.0  ...          55.0
#
#       Age_Range_at_Onset Age_Range_at_Onset_Coded  Last_Visit_Delta  \
# 16                  0-39                      0.0             547.0
# 17                 50-59                      2.0             347.0
# 23                 60-69                      3.0              90.0
# 27                 60-69                      3.0             364.0
# 95                 60-69                      3.0             358.0
# ...                  ...                      ...               ...
# 4566               60-69                      3.0             208.0
# 4650                 70+                      4.0               0.0
# 4737               50-59                      2.0             539.0
# 4765               50-59                      2.0             546.0
# 4770               50-59                      2.0             168.0
#
#      Last_Visit_from_Onset_in_Days  Last_Visit_from_Onset  Event_Dead  \
# 16                          1096.0                     36        True
# 17                           687.0                     22        True
# 23                           458.0                     15        True
# 27                           987.0                     32        True
# 95                           770.0                     25        True
# ...                            ...                    ...         ...
# 4566                         591.0                     19        True
# 4650                         188.0                      6        True
# 4737                        1281.0                     42        True
# 4765                        1083.0                     35        True
# 4770                         579.0                     19        True
#
#      Event_Dead_Delta  Event_Dead_Time_from_Onset_in_days  \
# 16                NaN                                 NaN
# 17                NaN                                 NaN
# 23                NaN                                 NaN
# 27                NaN                                 NaN
# 95                NaN                                 NaN
# ...               ...                                 ...
# 4566              NaN                                 NaN
# 4650              NaN                                 NaN
# 4737              NaN                                 NaN
# 4765              NaN                                 NaN
# 4770              NaN                                 NaN
#
#       Event_Dead_Time_from_Onset
# 16                           NaN
# 17                           NaN
# 23                           NaN
# 27                           NaN
# 95                           NaN
# ...                          ...
# 4566                         NaN
# 4650                         NaN
# 4737                         NaN
# 4765                         NaN
# 4770                         NaN
#
# [166 rows x 26 columns]
#       subject_id     Sex  Qty_Measurements_ALSFRS  \
# 16          4205    Male                      5.0
# 17          4429    Male                      4.0
# 23          5148    Male                      2.0
# 27          5806  Female                      4.0
# 95         16265  Female                      4.0
# ...          ...     ...                      ...
# 4566      960114  Female                      3.0
# 4650      975460    Male                      1.0
# 4737      993802    Male                      5.0
# 4765      999117    Male                      4.0
# 4770      999929    Male                      3.0
#
#       Qty_Measurements_VITALSIGNS  Qty_Measurements_FVC  Qty_Measurements_SVC  \
# 16                            5.0                   0.0                   0.0
# 17                            4.0                   0.0                   0.0
# 23                            2.0                   0.0                   0.0
# 27                            4.0                   0.0                   0.0
# 95                            4.0                   0.0                   0.0
# ...                           ...                   ...                   ...
# 4566                          3.0                   0.0                   0.0
# 4650                          1.0                   0.0                   0.0
# 4737                          5.0                   0.0                   0.0
# 4765                          4.0                   0.0                   0.0
# 4770                          3.0                   0.0                   0.0
#
#       Qty_Measurements_LABS  Qty_Measurements_HANDGRIPSTRENGTH  \
# 16                     20.0                                0.0
# 17                     16.0                                0.0
# 23                      8.0                                0.0
# 27                     16.0                                0.0
# 95                     16.0                                0.0
# ...                     ...                                ...
# 4566                   12.0                                0.0
# 4650                    4.0                                0.0
# 4737                   20.0                                0.0
# 4765                   16.0                                0.0
# 4770                   12.0                                0.0
#
#       Qty_Measurements_MUSCLESTRENGTH  Qty_Measurements  ...  Age_at_Onset  \
# 16                                0.0              30.0  ...          38.0
# 17                                0.0              24.0  ...          56.0
# 23                                0.0              12.0  ...          65.0
# 27                                0.0              24.0  ...          69.0
# 95                                0.0              24.0  ...          63.0
# ...                               ...               ...  ...           ...
# 4566                              0.0              18.0  ...          62.0
# 4650                              0.0               6.0  ...          78.0
# 4737                              0.0              30.0  ...          53.0
# 4765                              0.0              24.0  ...          54.0
# 4770                              0.0              18.0  ...          55.0
#
#       Age_Range_at_Onset Age_Range_at_Onset_Coded  Last_Visit_Delta  \
# 16                  0-39                      0.0             547.0
# 17                 50-59                      2.0             347.0
# 23                 60-69                      3.0              90.0
# 27                 60-69                      3.0             364.0
# 95                 60-69                      3.0             358.0
# ...                  ...                      ...               ...
# 4566               60-69                      3.0             208.0
# 4650                 70+                      4.0               0.0
# 4737               50-59                      2.0             539.0
# 4765               50-59                      2.0             546.0
# 4770               50-59                      2.0             168.0
#
#      Last_Visit_from_Onset_in_Days  Last_Visit_from_Onset  Event_Dead  \
# 16                          1096.0                     36        True
# 17                           687.0                     22        True
# 23                           458.0                     15        True
# 27                           987.0                     32        True
# 95                           770.0                     25        True
# ...                            ...                    ...         ...
# 4566                         591.0                     19        True
# 4650                         188.0                      6        True
# 4737                        1281.0                     42        True
# 4765                        1083.0                     35        True
# 4770                         579.0                     19        True
#
#      Event_Dead_Delta  Event_Dead_Time_from_Onset_in_days  \
# 16                NaN                              1096.0
# 17                NaN                               687.0
# 23                NaN                               458.0
# 27                NaN                               987.0
# 95                NaN                               770.0
# ...               ...                                 ...
# 4566              NaN                               591.0
# 4650              NaN                               188.0
# 4737              NaN                              1281.0
# 4765              NaN                              1083.0
# 4770              NaN                               579.0
#
#       Event_Dead_Time_from_Onset
# 16                          36.0
# 17                          22.0
# 23                          15.0
# 27                          32.0
# 95                          25.0
# ...                          ...
# 4566                        19.0
# 4650                         6.0
# 4737                        42.0
# 4765                        35.0
# 4770                        19.0
#
# [166 rows x 26 columns]

# %% [markdown]
# ### Calculate column `Event_Dead_Time_from_Onset`  (months) for those samples
# ### with `Event_Dead` = `True` (died) and  `Event_Dead_Delta` <> NaN

# %%
df_to_update = df.loc[
    (df.Event_Dead==True)
   &(df.Event_Dead_Delta.isnull()==False )
].copy()


df.loc[df_to_update.index,
      'Event_Dead_Time_from_Onset_in_days'] = df['Event_Dead_Delta'] + np.abs(df.Symptoms_Onset_Delta)

#calculate in MONTHS
in_months = df['Event_Dead_Time_from_Onset_in_days'].apply( lambda x: utils.calculate_months_from_days(x)) 

df.loc[df_to_update.index,
      'Event_Dead_Time_from_Onset'] = in_months


df.loc[df_to_update.index]
# Out:
#       subject_id     Sex  Qty_Measurements_ALSFRS  \
# 4            708    Male                     11.0
# 15          3981    Male                      5.0
# 31          7036  Female                      8.0
# 38          8258  Female                     11.0
# 45         10059  Female                      7.0
# ...          ...     ...                      ...
# 5169      419920    Male                     14.0
# 5184      854140    Male                     10.0
# 5192      548635    Male                     10.0
# 5205      891359  Female                     13.0
# 5207      930613  Female                     11.0
#
#       Qty_Measurements_VITALSIGNS  Qty_Measurements_FVC  Qty_Measurements_SVC  \
# 4                            12.0                   7.0                   0.0
# 15                            6.0                   4.0                   0.0
# 31                            8.0                   9.0                   0.0
# 38                           10.0                   6.0                   0.0
# 45                            5.0                   8.0                   0.0
# ...                           ...                   ...                   ...
# 5169                          0.0                   0.0                  11.0
# 5184                          0.0                   0.0                  10.0
# 5192                          0.0                   0.0                  10.0
# 5205                          0.0                   0.0                  13.0
# 5207                          0.0                   0.0                  11.0
#
#       Qty_Measurements_LABS  Qty_Measurements_HANDGRIPSTRENGTH  \
# 4                     404.0                                0.0
# 15                    150.0                                0.0
# 31                    264.0                                0.0
# 38                    180.0                               16.0
# 45                    160.0                                0.0
# ...                     ...                                ...
# 5169                  386.0                               15.0
# 5184                  385.0                               16.0
# 5192                  388.0                               16.0
# 5205                  465.0                               22.0
# 5207                  352.0                               18.0
#
#       Qty_Measurements_MUSCLESTRENGTH  Qty_Measurements  ...  Age_at_Onset  \
# 4                                 0.0             434.0  ...          43.0
# 15                                0.0             165.0  ...          62.0
# 31                                0.0             289.0  ...          64.0
# 38                              205.0             428.0  ...          67.0
# 45                                0.0             180.0  ...          69.0
# ...                               ...               ...  ...           ...
# 5169                            144.0             570.0  ...          38.0
# 5184                            128.0             549.0  ...          55.0
# 5192                            128.0             552.0  ...          62.0
# 5205                            176.0             689.0  ...          58.0
# 5207                            144.0             536.0  ...          56.0
#
#       Age_Range_at_Onset Age_Range_at_Onset_Coded  Last_Visit_Delta  \
# 4                  40-49                      1.0             250.0
# 15                 60-69                      3.0              82.0
# 31                 60-69                      3.0             303.0
# 38                 60-69                      3.0             587.0
# 45                 60-69                      3.0             194.0
# ...                  ...                      ...               ...
# 5169                0-39                      0.0             388.0
# 5184               50-59                      2.0             288.0
# 5192               60-69                      3.0             259.0
# 5205               50-59                      2.0             394.0
# 5207               50-59                      2.0             370.0
#
#      Last_Visit_from_Onset_in_Days  Last_Visit_from_Onset  Event_Dead  \
# 4                           1320.0                     43        True
# 15                           292.0                      9        True
# 31                           706.0                     23        True
# 38                          1498.0                     49        True
# 45                           483.0                     15        True
# ...                            ...                    ...         ...
# 5169                         691.0                     22        True
# 5184                         618.0                     20        True
# 5192                         833.0                     27        True
# 5205                        1375.0                     45        True
# 5207                        1031.0                     33        True
#
#      Event_Dead_Delta  Event_Dead_Time_from_Onset_in_days  \
# 4               250.0                              1320.0
# 15               82.0                               292.0
# 31              303.0                               706.0
# 38              587.0                              1498.0
# 45              194.0                               483.0
# ...               ...                                 ...
# 5169            388.0                               691.0
# 5184            288.0                               618.0
# 5192            259.0                               833.0
# 5205            394.0                              1375.0
# 5207            370.0                              1031.0
#
#       Event_Dead_Time_from_Onset
# 4                           43.0
# 15                           9.0
# 31                          23.0
# 38                          49.0
# 45                          15.0
# ...                          ...
# 5169                        22.0
# 5184                        20.0
# 5192                        27.0
# 5205                        45.0
# 5207                        33.0
#
# [1084 rows x 26 columns]

# %% [markdown]
# ### Show total of samples non-NaN (and NaN) for each column

# %%
utils.show_columns_stats(df)
# Out:
# subject_id........................ =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=  5230
# Sex............................... =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=     2
# Qty_Measurements_ALSFRS........... =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=    32
# Qty_Measurements_VITALSIGNS....... =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=    55
# Qty_Measurements_FVC.............. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=    20
# Qty_Measurements_SVC.............. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=    17
# Qty_Measurements_LABS............. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=   953
# Qty_Measurements_HANDGRIPSTRENGTH. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=    38
# Qty_Measurements_MUSCLESTRENGTH... =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=   293
# Qty_Measurements.................. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=  1087
# Symptoms_Onset_Delta.............. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=  1317
# Diagnosis_Delta................... =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=   960
# Site_Onset........................ =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=     4
# Diagnosis_Delay................... =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=    69
# Diagnosis_Delay_Str............... =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=     3
# Diagnosis_Delay_Coded............. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=     3
# Age_at_Onset...................... =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=    68
# Age_Range_at_Onset................ =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=     5
# Age_Range_at_Onset_Coded.......... =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=     5
# Last_Visit_Delta.................. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=   837
# Last_Visit_from_Onset_in_Days..... =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=  1551
# Last_Visit_from_Onset............. =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=   111
# Event_Dead........................ =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=     2
# Event_Dead_Delta.................. =  1084 rows (20.73%)  4146 with NaN (79.27%) Uniques=   545
# Event_Dead_Time_from_Onset_in_days =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=  1550
# Event_Dead_Time_from_Onset........ =  5230 rows (100.0%)     0 with NaN (  0.0%) Uniques=   111

# %% [markdown]
# ----
# ----
# ----
# # Delete unncessary columns

# %%
to_delete = [
    'Event_Dead_Delta',
    'Last_Visit_Delta',
    'Last_Visit_from_Onset',
    'Last_Visit_from_Onset_in_Days',
    'Event_Dead_Time_from_Onset_in_days',
]


df.drop(
    columns=to_delete, 
    inplace=True,
)

# %% [markdown]
# ----
# ----
# ----
# # Group deceased patients into `Short` and `Non-Short` survival groups:
# 	- Short     <=24 months     Code: 1
# 	- Non-Short >=25 months     Code: 0

# %%
df['Group_Survival'] = np.NaN
df['Group_Survival_Coded'] = np.NaN

# %%
to_update = df.loc[
    (df.Event_Dead==True)
   &(df.Event_Dead_Time_from_Onset<=24)
].copy()
df.loc[to_update.index, 'Group_Survival'] = 'Short'
df.loc[to_update.index, 'Group_Survival_Coded'] = 1


to_update = df.loc[
    (df.Event_Dead==True)
   &(df.Event_Dead_Time_from_Onset>=25)
].copy()
df.loc[to_update.index, 'Group_Survival'] = 'Non-Short'
df.loc[to_update.index, 'Group_Survival_Coded'] = 0


to_update = df.loc[
    (df.Event_Dead==False)
   &(df.Event_Dead_Time_from_Onset>=25)
].copy()
df.loc[to_update.index, 'Group_Survival'] = 'Non-Short'
df.loc[to_update.index, 'Group_Survival_Coded'] = 0

# %%
utils.plot_variable_distribution(series=df.Group_Survival)
# Out:
# ==============================================================================
# Column: Group_Survival  (DataType: object)
# ==============================================================================
# N         = 3795 [Non-NaN: 3795]
# Missingness: 1435 (27.44%)
#
# Summary Table:
#            count percentage
# Non-Short   3279     86.40%
# Short        516     13.60%

# %% [markdown]
# ----
# ----
# ----
# # Save the pre-processed data to CSV file

# %%
dir_dest = os.path.abspath('../03_preprocessed_data/')
csv_dest = f'{dir_dest}/_patient.csv'
utils.save_to_csv(df=df, csv_file=csv_dest)
# Out:
# 5230 samples were saved
